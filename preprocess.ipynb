# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import (StandardScaler, LabelEncoder)
from keras.utils import to_categorical

# %% [markdown]
# # Data Import

# %%
train_path = './Dataset/KDDtrain+.txt'
test_path = './Dataset/KDDTest+.txt'
val_path = './Dataset/KDDTest-21.txt'

# %%
features = ["duration", "protocol_type", "service", "flag", "src_bytes", "dst_bytes", "land", "wrong_fragment", "urgent", "hot",
            "num_failed_logins", "logged_in", "num_compromised", "root_shell", "su_attempted", "num_root", "num_file_creations", "num_shells",
            "num_access_files", "num_outbound_cmds", "is_host_login", "is_guest_login", "count", "srv_count", "serror_rate", "srv_serror_rate",
            "rerror_rate", "srv_rerror_rate", "same_srv_rate", "diff_srv_rate", "srv_diff_host_rate", "dst_host_count", "dst_host_srv_count",
            "dst_host_same_srv_rate", "dst_host_diff_srv_rate", "dst_host_same_src_port_rate", "dst_host_srv_diff_host_rate", "dst_host_serror_rate",
            "dst_host_srv_serror_rate", "dst_host_rerror_rate", "dst_host_srv_rerror_rate", "label", "difficulty"]

# %%
train = pd.read_csv(train_path, names=features)
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125973 entries, 0 to 125972
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     125973 non-null  int64
#  1   protocol_type                125973 non-null  object
#  2   service                      125973 non-null  object
#  3   flag                         125973 non-null  object
#  4   src_bytes                    125973 non-null  int64
#  5   dst_bytes                    125973 non-null  int64
#  6   land                         125973 non-null  int64
#  7   wrong_fragment               125973 non-null  int64
#  8   urgent                       125973 non-null  int64
#  9   hot                          125973 non-null  int64
#  10  num_failed_logins            125973 non-null  int64
#  11  logged_in                    125973 non-null  int64
# ...

# %%
train.drop(['difficulty'], axis=1, inplace=True)

# %% [markdown]
# # Data Analysis

# %%
train['label'].value_counts()
# Out:
# label
# normal             67343
# neptune            41214
# satan               3633
# ipsweep             3599
# portsweep           2931
# smurf               2646
# nmap                1493
# back                 956
# teardrop             892
# warezclient          890
# pod                  201
# guess_passwd          53
# buffer_overflow       30
# warezmaster           20
# land                  18
# imap                  11
# rootkit               10
# loadmodule             9
# ftp_write              8
# multihop               7
# phf                    4
# perl                   3
# spy                    2
# Name: count, dtype: int64

# %%
x_train, y_train = train.drop(['label'], axis=1), train['label']

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125973 entries, 0 to 125972
# Data columns (total 41 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     125973 non-null  int64
#  1   protocol_type                125973 non-null  object
#  2   service                      125973 non-null  object
#  3   flag                         125973 non-null  object
#  4   src_bytes                    125973 non-null  int64
#  5   dst_bytes                    125973 non-null  int64
#  6   land                         125973 non-null  int64
#  7   wrong_fragment               125973 non-null  int64
#  8   urgent                       125973 non-null  int64
#  9   hot                          125973 non-null  int64
#  10  num_failed_logins            125973 non-null  int64
#  11  logged_in                    125973 non-null  int64
# ...

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 125973 entries, 0 to 125972
# Series name: label
# Non-Null Count   Dtype
# --------------   -----
# 125973 non-null  object
# dtypes: object(1)
# memory usage: 984.3+ KB

# %% [markdown]
# # Data Cleaning

# %%
std_scaler = StandardScaler()


def standardization(df, col):
    for i in col:
        arr = df[i]
        arr = np.array(arr)
        df[i] = std_scaler.fit_transform(arr.reshape(len(arr), 1))
    return df


numeric_col = x_train.select_dtypes(include='number').columns
x_train = standardization(x_train, numeric_col)
x_train
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes      land  \
# 0      -0.110249           tcp  ftp_data   SF  -0.007679  -0.004919 -0.014089
# 1      -0.110249           udp     other   SF  -0.007737  -0.004919 -0.014089
# 2      -0.110249           tcp   private   S0  -0.007762  -0.004919 -0.014089
# 3      -0.110249           tcp      http   SF  -0.007723  -0.002891 -0.014089
# 4      -0.110249           tcp      http   SF  -0.007728  -0.004814 -0.014089
# ...          ...           ...       ...  ...        ...        ...       ...
# 125968 -0.110249           tcp   private   S0  -0.007762  -0.004919 -0.014089
# 125969 -0.107178           udp   private   SF  -0.007744  -0.004883 -0.014089
# 125970 -0.110249           tcp      smtp   SF  -0.007382  -0.004823 -0.014089
# 125971 -0.110249           tcp    klogin   S0  -0.007762  -0.004919 -0.014089
# 125972 -0.110249           tcp  ftp_data   SF  -0.007737  -0.004919 -0.014089
#
# ...

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_train
# Out:
# array([11, 11,  9, ..., 11,  9, 11])

# %%
x_train = pd.get_dummies(
    x_train, columns=['protocol_type', 'service', 'flag'], prefix="", prefix_sep="")

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125973 entries, 0 to 125972
# Columns: 122 entries, duration to SH
# dtypes: bool(84), float64(38)
# memory usage: 46.6 MB

# %%
x_train.shape, y_train.shape
# Out:
# ((125973, 122), (125973,))

# %%
x_train.to_csv("./Dataset/Preprocessed_data/x_train.csv", index=False)
pd.Series(y_train, name="Label").to_csv("./Dataset/Preprocessed_data/y_train.csv", index=False)

# %%
x_train, y_train = np.asarray(x_train, dtype="float32"), to_categorical(y_train, num_classes=23)

# %%
pd.DataFrame(x_train).to_csv("./Dataset/Preprocessed_data/x_train_DL.csv", index=False)

# %%
pd.DataFrame(y_train).to_csv("./Dataset/Preprocessed_data/y_train_DL.csv", index=False)
